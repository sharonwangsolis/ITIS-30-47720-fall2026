# %% [markdown]
# # Lecture 1 of ITIS-30 09/10/26

# %%
1 + 3
# Out:
# 4

# %%
3 * 3
# Out:
# 9

# %%
3 / 3
# Out:
# 1.0

# %%
'hello my name is prof sharon'
# we call this single quotes ''
# Out:
# 'hello my name is prof sharon'

# %%
"hello my name is prof sharon"
# we call this double quotes " "
# Out:
# 'hello my name is prof sharon'

# %%
hello my name is prof sharon
# this is a no-no. there does not exist a function/variable called hello in this notebook
# and python's way of telling me this is printing a SyntaxError flag below:
# Out:
#   Cell In[16], line 1
#     hello my name is prof sharon
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # comments start with a # (pound sign/hashtag) and are for human eyes only
# ## not executed as code
# ### if i want to write a comment here, it needs to start with a #

# %%
3 * 3
# Out:
# 9

# %%
'a' * 3
# when we multiply strings or letters/words in quotes, python will concatenate the strings together
# 'a' * 3 = 'a' + 'a' + 'a' = 'aaa'
# Out:
# 'aaa'

# %%
'a' + 'a' + 'a'
# Out:
# 'aaa'

# %%
'a' / 3
#python doesn't like this. we can't divide strings, although we can multiply them like above
#TypeError, no likey the combination of strings and integers with division
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 'a' / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
